# %%
import pandas as pd

data = pd.read_csv("/home/name-1/AI-Agent/frankscore/kenyan-dataset-issue/data/feature-generated/kenya_engineered_features.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54922 entries, 0 to 54921
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                54922 non-null  int64
#  1   tbl_loan_id                54922 non-null  float64
#  2   num_previous_loans         54922 non-null  int64
#  3   num_previous_defaults      48624 non-null  float64
#  4   past_default_rate          54922 non-null  float64
#  5   days_since_last_loan       48624 non-null  float64
#  6   avg_time_bw_loans          43603 non-null  float64
#  7   avg_past_amount            48624 non-null  float64
#  8   avg_past_daily_burden      48624 non-null  float64
#  9   std_past_amount            48624 non-null  float64
#  10  std_past_daily_burden      48624 non-null  float64
#  11  trend_in_amount            43603 non-null  float64
#  12  trend_in_burden            43603 non-null  float64
# ...

# %%
data['target'].value_counts()
# Out:
# target
# 0    53917
# 1     8072
# Name: count, dtype: int64

# %%
corr = data.corr(numeric_only=True)['target'].sort_values(ascending=False)
print(corr.head(10))
# Out:
# target                   1.000000
# interest_rate            0.641671
# repayment_intensity      0.317826
# lender_risk_profile      0.221415
# past_default_rate        0.206177
# duration                 0.191585
# num_previous_defaults    0.189850
# avg_past_amount          0.099032
# latest_amount_ma3        0.097221
# days_since_last_loan     0.086869
# Name: target, dtype: float64
